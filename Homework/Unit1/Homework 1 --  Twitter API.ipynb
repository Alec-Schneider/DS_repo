# %% [markdown]
# ## Homework 1: Advanced Track -- Harvest the Twitter API

# %% [markdown]
# **Objective:** Write a series of functions that allow you to dynamically harvest Twitter data.
#
# **Estimated Time to Complete:** 4-12 hours
#
# #### Sections
#
#  - **Section 1:** Setting up your developer account, using OAuth1 authentication (approx 45-120 minutes)
#  - **Sections 2 & 3:** Navigating the API documentation, getting your first query strings (approx 45-120 minutes)
#  - **Section 3:** Writing your API calls (approx 90 - 360 minutes)
#
# #### What You'll Turn In:
#  - A `.py` (not a Notebook!) file that contains the functions that you were prompted to create.  These should contain comments demonstrating why your code does what it does, and after it's run, the instructor should be able to make the appropriate function calls in Spyder or any other IDE.

# %% [markdown]
# ## Section 1:  Setting Up Your Developer Account

# %% [markdown]
# Most API's require you to do a little pre-work in order to be able to use them, so the first part of this homework assignment will be spent setting up your developer account so you have API Access.

# %% [markdown]
# **Step 1:  Create a Twitter Developer Account**
#
#  - Make sure you have a regular twitter account before you do this
#  - You can apply for a developer account here:  https://developer.twitter.com/en/apply-for-access
#   - Choose either a student or hobbyist/personal account

# %% [markdown]
# **Step 2:  Create An App**
#
# You don't have to intend to build an official software program to have an app.....this is just a way for you to get authentication keys to use with the API.
#
#  - Go to the menu in the upper right hand corner and click on **Your Name** > **Apps**
#  - Choose **Create An App**
#  - You'll be prompted to enter some information about your app.  Don't worry too much about this, it can say almost anything.  You'll be prompted to list websites where it will be hosted...this can be anything for now.  Use https://generalassemb.ly if you're undecided about what to put.

# %% [markdown]
# **Step 3: Create Your API Tokens**
#
# Now that you have an app, you can use its API tokens to go ahead and make requests like we did in class 3.  Like a lot of API's, the Twitter API uses something called OAuth authentication.
#
# If you didn't wait until the night before this assignment was due and have a spare 30 minutes, you can read a little about it here: https://oauth.net/
#
# In any event, you need API tokens in order to make requests.  Do the following:
#
#  - Go to the **Apps** section of your developer portal
#  - Click on the **Details** button for the app that you just created
#  - Click on the **Keys & Tokens** tab
#  - Generate your Access Token and Access Token Secret keys.  You'll need to write these down when you're done
#
# Now you're ready to make requests to the Twitter api.  Everytime you make a request, you'll need to include the 4 tokens you just created.  (You can always regenerate them for whatever reason).

# %% [markdown]
# **Step 4:  Your First Request**
#
# To make requests to the Twitter API you're going to need a module which is **not** already pre-installed in Anaconda. You'll need to install it via PIP, which is python's package manager.  It's called `requests_oauthlib`.  You can install this via Anaconda Prompt or Terminal by simply typing in the command `pip install requests_oauthlib`, and then you'll be finished.
#
# The logistics of making an OAuth1 authenticated request are very similar to what was done in class 3, but with a few additional steps.  You can see how to do it here:  https://requests.readthedocs.io/en/master/user/authentication/#oauth-1-authentication.  The only thing you'll need to change is the info for your API tokens that are passed into the `OAuth1()` function.
#
# Try making a request to the following URL to confirm that it works: 'https://api.twitter.com/1.1/account/verify_credentials.json'

# %%
import requests
from requests_oauthlib import OAuth1

help(OAuth1)
# Out:
# Help on class OAuth1 in module requests_oauthlib.oauth1_auth:
#
# class OAuth1(requests.auth.AuthBase)
#  |  Signs the request using OAuth 1 (RFC5849)
#  |
#  |  Method resolution order:
#  |      OAuth1
#  |      requests.auth.AuthBase
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __call__(self, r)
#  |      Add OAuth parameters to the request.
#  |
#  |      Parameters may be included from the body if the content-type is
#  |      urlencoded, if no content type is set a guess is made.
#  |
#  |  __init__(self, client_key, client_secret=None, resource_owner_key=None, resource_owner_secret=None, callback_uri=None, signature_method='HMAC-SHA1', signature_type='AUTH_HEADER', rsa_key=None, verifier=None, decoding='utf-8', client_class=None, force_include_body=False, **kwargs)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  client_class = <class 'oauthlib.oauth1.rfc5849.Client'>
#  |      A client used to sign OAuth 1.0 RFC 5849 requests.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from requests.auth.AuthBase:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %%
url = 'https://api.twitter.com/1.1/account/verify_credentials.json'
auth = OAuth1('sWjlYbgUANObCyZ1YPeKerP3K', 'j7tbbJmTGKFqSG1RXjNfVU3dY9j54oQ0UU0tAwDqmtuE4Fv8BD'
              ,'1223025397035606017-VuF2llYRiSepf0XS8O8i4nikToLCr9', 'BIX3EPvTLGoyBrDnp9cXSeQeq6xeoz6gl73xcCAfWidg9')

# req = requests.get(url, auth=auth)
# type(req)

# %%
req.json()
# Out:
# {'id': 1223025397035606017,
#  'id_str': '1223025397035606017',
#  'name': 'Alec Schneider',
#  'screen_name': 'AlecSchneider10',
#  'location': '',
#  'description': '',
#  'url': None,
#  'entities': {'description': {'urls': []}},
#  'protected': False,
#  'followers_count': 0,
#  'friends_count': 0,
#  'listed_count': 0,
#  'created_at': 'Thu Jan 30 23:29:24 +0000 2020',
#  'favourites_count': 0,
#  'utc_offset': None,
#  'time_zone': None,
#  'geo_enabled': False,
#  'verified': False,
#  'statuses_count': 0,
#  'lang': None,
#  'contributors_enabled': False,
#  'is_translator': False,
#  'is_translation_enabled': False,
#  'profile_background_color': 'F5F8FA',
#  'profile_background_image_url': None,
#  'profile_background_image_url_https': None,
#  'profile_background_tile': False,
#  'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#  'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#  'profile_link_color': '1DA1F2',
#  'profile_sidebar_border_color': 'C0DEED',
#  'profile_sidebar_fill_color': 'DDEEF6',
#  'profile_text_color': '333333',
#  'profile_use_background_image': True,
#  'has_extended_profile': True,
#  'default_profile': True,
#  'default_profile_image': True,
#  'can_media_tag': True,
#  'followed_by': False,
#  'following': False,
#  'follow_request_sent': False,
#  'notifications': False,
#  'translator_type': 'none',
#  'suspended': False,
#  'needs_phone_verification': False}

# %% [markdown]
# If you get your json object back, then you're good to go.

# %% [markdown]
# ## Section 2: Searching Tweets

# %% [markdown]
# Most websites you access will have a long string attached to the end of them that look something like this:  `http://thewebsite.com/?year=2019&color=golden%20yellow%20user_id=48549395959438`.
#
# Most people have no reason to pay attention to any of this, but all the special symbols at the end are basically encoded commands that say 'return a website that displays x,y,z characteristics.'
#
# When accessing api data, it basically works the same way.

# %% [markdown]
# **Step 1:  Set Up Your First Query String**

# %% [markdown]
# If you go into Twitter and search for the term `Data Science`, you should be brought to a url that looks like this:  `https://twitter.com/search?q=Data%20Science&src=typed_query`
#
# If you'd like, you can drop the `&src=typed_query` from the url and still get the same results.
#
# There are some important details to pay attention to:
#
#  - Like class 3 when we worked with GitHub, there is a **base url**.  In this case it's `https://twitter.com/search`
#  - Whenever you enter a search for something, the base url will be followed by something that looks like `?q=My%20Search%20Term`
#   - The `?` marks the beginning of the query string.  This basically says 'initiate a request with whatever parameters that follow'
#   - The `q` is a **parameter**, essentially some condition to pass into the query string that determines what results will be given back to you.
#
# **Useful Thing To Do Right Now:** Go back to the Twitter search page, and just try searching for different things, and notice what shows up after the `q=`.  Here are some questions to ask yourself:
#
#  - How are white spaces encoded?  Ie, if you search for `Jonathan Bechtel` in the search box, what shows up to account for the space between the two words?
#  - What about hash symbols?  If you search for `#MeToo`, `#GirlsWhoCode` or `#DataScience`, what happens with that `#` symbol?
#  - Once you get the hang of this, see if you can just re-create some searches yourself by creating the url directly, and bypassing the search box altogether.
#
# Now, let's try and make a request for a search for `Data Science`.
#
# If you look at Twitter's docs, you'll see that the base url for the search API is `'https://api.twitter.com/1.1/search/tweets.json`
#
# This means you have to add the `?q=Whatever%20Word%20%Goes%20Here` to the end to complete the search.
#
# So go ahead, and see if you can create your API call for a search for the term `Data Science`.
#
# If you did it correctly, you should have a dictionary with a key called `statuses`, and it'll be a list with all of the tweets returned by your search.

# %%
base_url = 'https://api.twitter.com/1.1/search/tweets.json'
q = 'q='
space = '%20'
chars = {'space': (' ', space)}
query1 = base_url + '?' + q + 'Data Science'.replace(*chars['space'])
ds = requests.get(query1, auth=auth)

# %% [markdown]
# For good measure, try doing a search for tweets relating to `#MeToo` as well.

# %%
chars['hashtag'] = ('#', '%23')
query2 = base_url + '?' + q + '#MeToo'.replace(*chars['hashtag'])
metoo = ds = requests.get(query2, auth=auth)

# %% [markdown]
# **Step 2:  Adding Parameters to Your Query String**

# %% [markdown]
# Query strings basically have two parts:
#
#  - What follows fhe `?` encodes the actual text to search for, using utf-8 encoding to account for special characters.  This is required.
#  - You can also add additional search parameters, which are encoded by `&`. They dictate what kinds of results are returned.
#   - For example, a parameter you can use in Twitter's search API is `count`, which tells you how many results to return.  The default is 15, but you can return up to 100.  So if we wanted to search for tweets and return 50 results our query string would look like the following:
#     `https://api.twitter.com/1.1/search/tweets.json?My%20Search%20String&count=50`
#   - You can add as many of these parameters to your string as you'd like.  So for example, if we wanted to include parameters for `count` and `result_type`, we could do the following: `https://api.twitter.com/1.1/search/tweets.json?My%20Search%20String&count=50&result_type=mixed`
#
# To get the hang of this, try searching for tweets that mention the hashtag `#DeepLearning`, and return 75 results.

# %%
query3 = base_url + '?' + q + '#DeepLearning'.replace(*chars['hashtag']) + '&count=75'
dl = requests.get(query3, auth=auth)
#dl.json()

# %% [markdown]
# Try adding a second parameter.  You can find the list here:  https://developer.twitter.com/en/docs/tweets/search/api-reference/get-search-tweets

# %%
query4 = base_url + '?' + q + '#SuperBowl'.replace(*chars['hashtag']) + '&count=75' + '&result_type=popular'
sb = requests.get(query4, auth=auth)
type(sb.json())
# Out:
# dict

# %% [markdown]
# ## Section 3: Searching Users

# %% [markdown]
# The last section of the API you'll need to get the hang of before you're let loose is the users API, which allows you to search for users and get their followers, friends, etc, as opposed to tweets which fit a particular criteria.  This part is pretty similar to the advanced lab in class 3, so if you saw how that worked then you shouldn't need much instruction.
#
# But if you're seeing this with fresh eyes, you'll want to spend 15-20 minutes to make sure you understand this part.
#
# Official documentation can be found here:  https://developer.twitter.com/en/docs/accounts-and-users/follow-search-get-users/overview
#
# So, as an example, if you want to get a list of someone's followers, you use the base url `https://api.twitter.com/1.1/followers/list.json` and then enter your query string to get a list of that persons followers.
#
# List of parameters to use can be found here:  https://developer.twitter.com/en/docs/accounts-and-users/follow-search-get-users/api-reference
#
# One possible parameter to use is `screen_name`, so if you wanted to get a list of someone's followers based on their screen name (the handle that begins with an @), then you would set up your API call to look something like:
#
# `https://api.twitter.com/1.1/followers/list.json?screen_name=persons_screenname`
#
# Note that you exclude the `@`.
#
# **Your turn:** Pull in the list of General Assembly's followers.  General Assembly's handle is `@GA`
#
# Note that this won't return the whole list of GA's users.  If you want to do that you have to use cursoring:  https://developer.twitter.com/en/docs/basics/cursoring.  This is the topic of your bonus assignment.

# %%
flwerlist = 'https://api.twitter.com/1.1/followers/list.json'
query5 = requests.get(flwerlist + '?' + 'screen_name=GA', auth=auth)
query5.json()['users'][0].keys()
# Out:
# dict_keys(['id', 'id_str', 'name', 'screen_name', 'location', 'description', 'url', 'entities', 'protected', 'followers_count', 'friends_count', 'listed_count', 'created_at', 'favourites_count', 'utc_offset', 'time_zone', 'geo_enabled', 'verified', 'statuses_count', 'lang', 'status', 'contributors_enabled', 'is_translator', 'is_translation_enabled', 'profile_background_color', 'profile_background_image_url', 'profile_background_image_url_https', 'profile_background_tile', 'profile_image_url', 'profile_image_url_https', 'profile_link_color', 'profile_sidebar_border_color', 'profile_sidebar_fill_color', 'profile_text_color', 'profile_use_background_image', 'has_extended_profile', 'default_profile', 'default_profile_image', 'can_media_tag', 'followed_by', 'following', 'live_following', 'follow_request_sent', 'notifications', 'muting', 'blocking', 'blocked_by', 'translator_type'])

# %% [markdown]
# ## Section 4: Functions

# %% [markdown]
# This section details the functions you have to write and turn in as part of your homework assignment.
#
# Please read the requirements carefully.
#
# **What you'll turn in:** A `.py` file with all of the functions written.  We should be able to load this into an IDE, run the file, and then call your functions to verify how and if they work. This file should also be properly commented so we can follow your line of reasoning.
#
# The functions you'll be prompted to write will be defined in the following ways:
#
#  - **name:** the name of the function
#  - **returns:** what the function should return
#  - **arguments:** arguments to include inside the function in order to specify how it should behave.
#
#  **Note:** The free API has limitations built into it, so this means from time-to-time you'll only be able to return some of the results from the API.  This is fine.  It's understood and recognized that your functions won't be able to return an entire list of someone's users or other such things, so as long as your work delivers the best it can under present circumstances you'll be in good shape.
#
#  **Other Note:** Every aspect of the API that you need to use can be found on either of these pages.
#
#  Search API:  https://developer.twitter.com/en/docs/tweets/search/api-reference/get-search-tweets
#
#  Users API: https://developer.twitter.com/en/docs/accounts-and-users/follow-search-get-users/api-reference
#
# **Remarks About Your Final Work**
#
#  - It's okay if you get stuck somewhere.  If there's one item that you can't figure out and it doesn't quite work right, it's probably best to move on and try other things.  Again, try and explain what you were looking to do.  You'll pass if you give an honest effort.
#  - There's potentially a lot of error handling you could do to verify user input is correct, but you can leave that alone for now.  Just make sure the core purpose of the function works the way it's supposed to.
#  - While you're working on this, it's possible you may bump into your API limits.  Keep this in mind if you have a function that's working, but 45 minutes later it doesn't and you haven't changed anything.  This usually means the data you're getting back from your API calls isn't what it's supposed to be because you've exhausted your limits. We won't hold you to double checking for all of this in your functions.
#  - In the file you turn in, make sure your requests are referencing your API tokens, so that way we can run your file right away.  Ie, make sure somewhere in your script you have a variable at the top that reads `tokens = OAuth1('token1', 'token2', 'token3', 'token4')` so it can be used for your requests inside the file.

# %% [markdown]
# ##### Function 1 (Required)

# %% [markdown]
# **Name:** `find_user`
#
# **Returns:** dictionary that represents user object returned by Twitter's API
#
# **Arguments:**
#  - `screen_name`: str, required; Twitter handle to search for.  **Can include the @ symbol.  The function should check for this and remove it if necessary.**
#  - `keys`: list, optional; list that contains keys to return about user object.  If not specified, then function should return the entire user object.  **These only need to be outer keys.** If they are keys nested within another key, you don't have to account for this.
#
# **To test:** We'll test your function in the following ways:
#
#  - `find_user('@GA')`
#  - `find_user('GA')`
#  - `find_user('GA', keys=['name', 'screen_name', 'followers_count', 'friends_count'])`

# %%
usr = 'https://api.twitter.com/1.1/users/show.json?screen_name='
query6 = requests.get(usr + 'GA', auth=auth)
query6.json().keys()
# Out:
# dict_keys(['id', 'id_str', 'name', 'screen_name', 'location', 'profile_location', 'description', 'url', 'entities', 'protected', 'followers_count', 'friends_count', 'listed_count', 'created_at', 'favourites_count', 'utc_offset', 'time_zone', 'geo_enabled', 'verified', 'statuses_count', 'lang', 'status', 'contributors_enabled', 'is_translator', 'is_translation_enabled', 'profile_background_color', 'profile_background_image_url', 'profile_background_image_url_https', 'profile_background_tile', 'profile_image_url', 'profile_image_url_https', 'profile_banner_url', 'profile_link_color', 'profile_sidebar_border_color', 'profile_sidebar_fill_color', 'profile_text_color', 'profile_use_background_image', 'has_extended_profile', 'default_profile', 'default_profile_image', 'can_media_tag', 'followed_by', 'following', 'follow_request_sent', 'notifications', 'translator_type'])

# %%
query7 = requests.get(usr + 'sdlkfjsfewjclmfocmeijc', auth=auth)
query7.json()
# Out:
# {'errors': [{'code': 50, 'message': 'User not found.'}]}

# %% [markdown]
# ##### Function 2 (Required)

# %% [markdown]
# **Name:** `find_hashtag`
#
# **Returns:** list of data objects that contain information about each tweet that matches the hashtag provided as input.
#
# **Arguments:**
#  - `hashtag`: str, required; text to use as a hashtag search.
#  - `count`: int, optional; number of results to return
#  - `search_type`: str, optional; type of results to return.  should accept 3 different values:
#    - `mixed`:   return mix of most recent and most popular results
#    - `recent`:  return most recent results
#    - `popular`: return most popular results
#
# **Note:** User should **not** have to actually use the `#` character for the `hashtag` argument.  The function should check to see if it's there, and if not, add it in for them.
#
# **To Test:**  We'll check your function in the following ways:
#  - `find_hashtag('DataScience')`
#  - `find_hashtag('#DataScience')`
#  - `find_hashtag('#DataScience', count=100)`, and double check the `statuses` key to make sure it contains the right amount of results.
#  - `find_hashtag('#DataScience', search_type='recent/mixed/popular')`

# %% [markdown]
# ##### Function 3 (Required)

# %% [markdown]
# **Name:** `get_followers`
#
# **Returns:** list of data objects for each of the users followers, returning values for the `name`, `followers_count`, `friends_count`, and `screen_name` key for each user.
#
# **Arguments:**
#
#  - `screen_name`: str, required; Twitter handle to search for.  **Results should not depend on user inputting the @ symbol.**
#  - `keys`: list, required;  keys to return for each user.  default value: [`name`, `followers_count`, `friends_count`, `screen_name`]; if something else is listed, values for those keys should be returned
#  - `to_df`: bool, required; default value: False; if True, return results in a dataframe.  Every value provided in the `keys` argument should be its own column, with rows populated by the corresponding values for each one for every user.
#
# **To Test:** We'll test your functions in the following ways:
#
#  - `get_followers('@GA')`
#  - `get_followers('GA')`
#  - `get_followers('GA', keys=['name', 'followers_count'])`
#  - `get_followers('GA', keys=['name', 'followers_count'], to_df=True)`
#  - `get_followers('GA', to_df=True)`

# %% [markdown]
# ##### Function 4 (Optional)

# %% [markdown]
# **Name:** `friends_of_friends`
#
# **Returns:** list of data objects for each user that two Twitter users have in common
#
# **Arguments:**
#
#  - `names`: list, required; list of two Twitter users to compare friends list with
#  - `keys`: list, optional; list of keys to return for information about each user.  Default value should be to return the entire data object.
#  - `to_df`: bool, required; default value: False; if True, returns results in a dataframe.
#
# **To Test:** We'll test your function in the following ways:
#
#  - `friends_of_friends(['Beyonce', 'MariahCarey'])`
#  - `friends_of_friends(['@Beyonce', '@MariahCarey'], to_df=True)`
#  - `friends_of_friends(['Beyonce', 'MariahCarey'], keys=['id', 'name'])`
#  - `friends_of_friends(['Beyonce', 'MariahCarey'], keys=['id', 'name'], to_df=True)`
#
# Each of these should return 3 results.
#
# **Hint:** The `id` key is the unique identifier for someone, so if you want to check if two people are the same this is the best way to do it.

# %% [markdown]
#  ##### Function 5 (Optional)

# %% [markdown]
# Rewrite the `friends_of_friends` function, except this time include an argument called `full_search`, which accepts a boolean value.  If set to `True`, use cursoring to cycle through the complete set of users for the users provided.
#
# The twitter API only returns a subset of users in your results to save bandwidth, so you have to cycle through multiple result sets to get all of the values.
#
# You can read more about how this works here:  https://developer.twitter.com/en/docs/basics/cursoring
#
# Basically you have to do a `while` loop to continually make a new request using the values stored in the `next_cursor` key as part of your next query string until there's nothing left to search.
#
# **Note:** We're using the free API, so we're operating under some limitations.  One of them being that you can only make 15 API calls in a 15 minute span.  You can also only return up to 200 results per cursor, so this means you won't be able to completely search for everyone even if you set this up correctly.
#
# That's fine, just do what you can under the circumstances.
#
# **To Test:** To test your function, we'll run the following function calls:
#
#  - `friends_of_friends(['ezraklein', 'tylercowen'], full_search=True)`
#
# **Hint:** Chances are you will exhaust your API limits quite easily in this function depending on who you search for.  Depending on how you have things set up, this could cause error messages to arise when things are otherwise fine.  Remember in class 3 when we were getting those weird dictionaries back because our limits were used up?  We won't hold you accountable for handling this inside your function, although it could make some things easier for your own testing.
#
# Good luck!

# %%
import twitterfuncs as twt
twt.friends_of_friends(['Beyonce', 'MariahCarey'], to_df=True)
# Out:
#                     id               id_str                    name  \
# 0  1217183291427774465  1217183291427774465  Marcolino Balda Mateus
#
#     screen_name location             description   url  \
# 0  mateus_balda   Angola  I'm teacher and singer  None
#
#                         entities  protected  followers_count  ...  \
# 0  {'description': {'urls': []}}      False               11  ...
#
#    can_media_tag  followed_by following  live_following follow_request_sent  \
# 0           True        False     False           False               False
#
#   notifications  muting  blocking  blocked_by translator_type
# 0         False   False     False       False            none
#
# [1 rows x 49 columns]

# %%
flwerlist = 'https://api.twitter.com/1.1/followers/list.json'
jsonlst = []
cursor = -1
while cursor:
    query5 = requests.get(flwerlist + '?' + 'screen_name=GA' + '&cursor=%s' % cursor, auth=auth)
    js = query5.json()
    cursor = js['next_cursor']
    print('Cursor now ==>', cursor)
    jsonlst.append(js)
# Out:
# {'users': [{'id': 16090812, 'id_str': '16090812', 'name': 'Heather Rosen', 'screen_name': 'VAfranchise', 'location': 'Wash DC metro', 'description': 'Business Advisor, Career Transition Specialist, Expert on Franchises, Theatre Reviewer, Arts Addict', 'url': 'https://t.co/RqfeIWPnFg', 'entities': {'url': {'urls': [{'url': 'https://t.co/RqfeIWPnFg', 'expanded_url': 'http://www.frannet.com/hrosen', 'display_url': 'frannet.com/hrosen', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 355, 'friends_count': 589, 'listed_count': 23, 'created_at': 'Tue Sep 02 01:19:59 +0000 2008', 'favourites_count': 457, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 5029, 'lang': None, 'status': {'created_at': 'Sat Feb 01 13:00:07 +0000 2020', 'id': 1223591861220249605, 'id_str': '1223591861220249605', 'text': 'Time management and staying focused are difficult tasks for most entrepreneurs and business owners. When your to-do… https://t.co/xRdiyZkwvG', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/xRdiyZkwvG', 'expanded_url': 'https://twitter.com/i/web/status/1223591861220249605', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'source': '<a href="http://www.rallio.com" rel="nofollow">Rallio</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'lang': 'en'}, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '2A6EBB', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme8/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme8/bg.gif', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1967187771/HeatherHeadshotNJsmall1_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1967187771/HeatherHeadshotNJsmall1_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/16090812/1580477447', 'profile_link_color': 'EA7125', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'EADEAA', 'profile_text_color': '333333', 'profile_use_background_image': False, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'can_media_tag': True, 'followed_by': False, 'following': False, 'live_following': False, 'follow_request_sent': False, 'notifications': False, 'muting': False, 'blocking': False, 'blocked_by': False, 'translator_type': 'none'}, {'id': 1195866190163464192, 'id_str': '1195866190163464192', 'name': 'Daniel Simone', 'screen_name': 'DanielSimone20', 'location': 'Chicago, Illinois', 'description': '', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 15, 'friends_count': 271, 'listed_count': 0, 'created_at': 'Sun Nov 17 00:48:26 +0000 2019', 'favourites_count': 438, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 568, 'lang': None, 'status': {'created_at': 'Sun Feb 02 15:11:27 +0000 2020', 'id': 1223987297957433344, 'id_str': '1223987297957433344', 'text': '@TMobile #5GThatWorks awesome!!', 'truncated': False, 'entities': {'hashtags': [{'text': '5GThatWorks', 'indices': [9, 21]}], 'symbols': [], 'user_mentions': [{'screen_name': 'TMobile', 'name': 'T-Mobile', 'id': 17338082, 'id_str': '17338082', 'indices': [0, 8]}], 'urls': []}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': 1223986848936218625, 'in_reply_to_status_id_str': '1223986848936218625', 'in_rep ...
# dict_keys(['users', 'next_cursor', 'next_cursor_str', 'previous_cursor', 'previous_cursor_str', 'total_count'])
# Cursor now ==> 1657403181071862900
# {'users': [{'id': 1094657957776760833, 'id_str': '1094657957776760833', 'name': 'Mooninspired', 'screen_name': 'Traci18631399', 'location': '', 'description': "I'm a huge book nerd! Actually, just a nerd...lol", 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 35, 'friends_count': 184, 'listed_count': 0, 'created_at': 'Sun Feb 10 18:02:49 +0000 2019', 'favourites_count': 192, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 40, 'lang': None, 'status': {'created_at': 'Fri Jan 31 17:52:40 +0000 2020', 'id': 1223303093464567810, 'id_str': '1223303093464567810', 'text': 'Kick It With Keith Urban! https://t.co/awWqr7D9iV', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/awWqr7D9iV', 'expanded_url': 'http://theboot.com', 'display_url': 'theboot.com', 'indices': [26, 49]}]}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'lang': 'en'}, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1094658096608227329/ck8u71-a_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1094658096608227329/ck8u71-a_normal.jpg', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'can_media_tag': True, 'followed_by': False, 'following': False, 'live_following': False, 'follow_request_sent': False, 'notifications': False, 'muting': False, 'blocking': False, 'blocked_by': False, 'translator_type': 'none'}, {'id': 937986425340936192, 'id_str': '937986425340936192', 'name': '安迪 沃霍尔', 'screen_name': '9c4fbHvG3ZEyvGO', 'location': '广东 深圳', 'description': '', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 12, 'friends_count': 315, 'listed_count': 0, 'created_at': 'Tue Dec 05 10:06:05 +0000 2017', 'favourites_count': 7, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 7, 'lang': None, 'status': {'created_at': 'Sun Feb 02 04:05:04 +0000 2020', 'id': 1223819598425808896, 'id_str': '1223819598425808896', 'text': '@daotui2019 30年之内，中共没有下台的可能。', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'daotui2019', 'name': 'Daotui2019', 'id': 1151694864532119552, 'id_str': '1151694864532119552', 'indices': [0, 11]}], 'urls': []}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': 1223779102659756033, 'in_reply_to_status_id_str': '1223779102659756033', 'in_reply_to_user_id': 1151694864532119552, 'in_reply_to_user_id_str': '1151694864532119552', 'in_reply_to_screen_name': 'daotui2019', 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'zh'}, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': Fal ...
# dict_keys(['users', 'next_cursor', 'next_cursor_str', 'previous_cursor', 'previous_cursor_str', 'total_count'])
# Cursor now ==> 1657387733240755033
# {'users': [{'id': 1619141760, 'id_str': '1619141760', 'name': 'zencodecat', 'screen_name': 'hanajjade', 'location': '', 'description': '🌈🌻🌲', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 13, 'friends_count': 94, 'listed_count': 0, 'created_at': 'Thu Jul 25 02:37:20 +0000 2013', 'favourites_count': 90, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 24, 'lang': None, 'status': {'created_at': 'Tue Oct 01 18:54:16 +0000 2019', 'id': 1179107278416420866, 'id_str': '1179107278416420866', 'text': 'RT @necolas: In a queue at the supermarket. A toddler is intensely looking at me over her mother\'s shoulder, and saying "he\'s very tired mo…', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'necolas', 'name': 'Nicolas', 'id': 24974216, 'id_str': '24974216', 'indices': [3, 11]}], 'urls': []}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Tue Oct 01 01:07:12 +0000 2019', 'id': 1178838741193879552, 'id_str': '1178838741193879552', 'text': 'In a queue at the supermarket. A toddler is intensely looking at me over her mother\'s shoulder, and saying "he\'s ve… https://t.co/AOpS8JwmSr', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/AOpS8JwmSr', 'expanded_url': 'https://twitter.com/i/web/status/1178838741193879552', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 107, 'favorite_count': 682, 'favorited': False, 'retweeted': False, 'lang': 'en'}, 'is_quote_status': False, 'retweet_count': 107, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'en'}, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/901851232628760576/qFXHzZr3_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/901851232628760576/qFXHzZr3_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1619141760/1543087476', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'can_media_tag': True, 'followed_by': False, 'following': False, 'live_following': False, 'follow_request_sent': False, 'notifications': False, 'muting': False, 'blocking': False, 'blocked_by': False, 'translator_type': 'none'}, {'id': 1041597554394361856, 'id_str': '1041597554394361856', 'name': 'enrobsOdrahciR', 'screen_name': 'enrobsOdrahciR', 'location': '', 'description': '', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 0, 'friends_count': 85, 'listed_count': 0, 'created_at': 'Mon Sep 17 07:59:43 +0000 2018', 'favourites_count': 1, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 0, 'la ...
# dict_keys(['users', 'next_cursor', 'next_cursor_str', 'previous_cursor', 'previous_cursor_str', 'total_count'])
# Cursor now ==> 1657378147133835921
# {'users': [{'id': 801125562, 'id_str': '801125562', 'name': 'Melissa Medina', 'screen_name': 'Melissa13Medina', 'location': 'Buda, Texas', 'description': '24-Yr Multiple Sclerosis Survivor', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 120, 'friends_count': 699, 'listed_count': 0, 'created_at': 'Mon Sep 03 20:11:55 +0000 2012', 'favourites_count': 4663, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 2841, 'lang': None, 'status': {'created_at': 'Sun Feb 02 03:43:47 +0000 2020', 'id': 1223814243050557440, 'id_str': '1223814243050557440', 'text': '@TheSill Wow, pricey.', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'TheSill', 'name': 'The Sill', 'id': 417211294, 'id_str': '417211294', 'indices': [0, 8]}], 'urls': []}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': 1223801577783332865, 'in_reply_to_status_id_str': '1223801577783332865', 'in_reply_to_user_id': 417211294, 'in_reply_to_user_id_str': '417211294', 'in_reply_to_screen_name': 'TheSill', 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'en'}, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/453670483473334273/RiKH4adZ_normal.jpeg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/453670483473334273/RiKH4adZ_normal.jpeg', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': False, 'can_media_tag': True, 'followed_by': False, 'following': False, 'live_following': False, 'follow_request_sent': False, 'notifications': False, 'muting': False, 'blocking': False, 'blocked_by': False, 'translator_type': 'none'}, {'id': 1184145307644452866, 'id_str': '1184145307644452866', 'name': 'Janie', 'screen_name': 'Janie33117382', 'location': '', 'description': '', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 4, 'friends_count': 14, 'listed_count': 0, 'created_at': 'Tue Oct 15 16:33:51 +0000 2019', 'favourites_count': 0, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 1, 'lang': None, 'status': {'created_at': 'Tue Oct 15 16:45:30 +0000 2019', 'id': 1184148301375004672, 'id_str': '1184148301375004672', 'text': '@LiveKellyRyan OMG... kelly, you talk about “tragedy giggles” for funerals!!!😂😂😂🤣🤣. I have “tragedy giggles” when s… https://t.co/y3y6FI92SY', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'LiveKellyRyan', 'name': 'LIVEKellyRyan', 'id': 25092574, 'id_str': '25092574', 'indices': [0, 14]}], 'urls': [{'url': 'https://t.co/y3y6FI92SY', 'expanded_url': 'https://twitter.com/i/web/status/1184148301375004672', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': 25092574, 'in_reply_to_user_id_str': '25092574', 'in_reply_to_screen_name': 'LiveKellyRyan', 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang':  ...
# dict_keys(['users', 'next_cursor', 'next_cursor_str', 'previous_cursor', 'previous_cursor_str', 'total_count'])
# Cursor now ==> 1657366718665217369
# {'users': [{'id': 961546830, 'id_str': '961546830', 'name': 'Bryan Chiapparelli', 'screen_name': 'bchip21', 'location': 'Baltimore', 'description': '', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 19, 'friends_count': 250, 'listed_count': 0, 'created_at': 'Wed Nov 21 01:40:21 +0000 2012', 'favourites_count': 6, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 3, 'lang': None, 'status': {'created_at': 'Fri Jan 25 03:39:51 +0000 2019', 'id': 1088642579774824448, 'id_str': '1088642579774824448', 'text': '#Sweeps', 'truncated': False, 'entities': {'hashtags': [{'text': 'Sweeps', 'indices': [0, 7]}], 'symbols': [], 'user_mentions': [], 'urls': []}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'und'}, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', 'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': True, 'can_media_tag': True, 'followed_by': False, 'following': False, 'live_following': False, 'follow_request_sent': False, 'notifications': False, 'muting': False, 'blocking': False, 'blocked_by': False, 'translator_type': 'none'}, {'id': 1203150133522817024, 'id_str': '1203150133522817024', 'name': 'OutlawtheMastiff', 'screen_name': 'OutlawtheCathy', 'location': '', 'description': "I'm a Winner!", 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 12, 'friends_count': 239, 'listed_count': 0, 'created_at': 'Sat Dec 07 03:12:48 +0000 2019', 'favourites_count': 44, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 569, 'lang': None, 'status': {'created_at': 'Sun Feb 02 14:49:18 +0000 2020', 'id': 1223981723601506304, 'id_str': '1223981723601506304', 'text': 'RT @SweepsAdvantage: Valpak Dash for Cash $5K Sweepstakes 👉https://t.co/36Rq3zXCZh https://t.co/msy8eTh0TF', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'SweepsAdvantage', 'name': 'Sweepstakes', 'id': 27023063, 'id_str': '27023063', 'indices': [3, 19]}], 'urls': [{'url': 'https://t.co/36Rq3zXCZh', 'expanded_url': 'https://www.sweepsadvantage.com/sweepstakes-search-Valpak.html', 'display_url': 'sweepsadvantage.com/sweepstakes-se…', 'indices': [59, 82]}], 'media': [{'id': 1223712626644934656, 'id_str': '1223712626644934656', 'indices': [83, 106], 'media_url': 'http://pbs.twimg.com/media/EPuAJoJU4AAR31N.jpg', 'media_url_https': 'https://pbs.twimg.com/media/EPuAJoJU4AAR31N.jpg', 'url': 'https://t.co/msy8eTh0TF', 'display_url': 'pic.twitter.com/msy8eTh0TF', 'expanded_url': 'https://twitter.com/SweepsAdvantage/status/1223712627932557313/photo/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'medium': {'w': 935, 'h': 312, 'resize': 'fit'}, 'small': {'w': 680, 'h': 227, 'resize': 'fit'}, 'large': {'w': 935, 'h': 312, 'resize': 'fit'}}, 'source ...
# dict_keys(['users', 'next_cursor', 'next_cursor_str', 'previous_cursor', 'previous_cursor_str', 'total_count'])
# Cursor now ==> 1657360449992106542
# {'users': [{'id': 64130270, 'id_str': '64130270', 'name': 'Jenna Debbs', 'screen_name': 'jdebbs', 'location': '', 'description': '', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': True, 'followers_count': 129, 'friends_count': 180, 'listed_count': 1, 'created_at': 'Sun Aug 09 07:13:19 +0000 2009', 'favourites_count': 2264, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 6556, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '32154F', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme10/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme10/bg.gif', 'profile_background_tile': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/802175900238413824/wv8i0AvU_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/802175900238413824/wv8i0AvU_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/64130270/1381099467', 'profile_link_color': 'F551E5', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': '7AC3EE', 'profile_text_color': '3D1957', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': False, 'default_profile_image': False, 'can_media_tag': True, 'followed_by': False, 'following': False, 'live_following': False, 'follow_request_sent': False, 'notifications': False, 'muting': False, 'blocking': False, 'blocked_by': False, 'translator_type': 'none'}, {'id': 1901190170, 'id_str': '1901190170', 'name': 'Chris Hurley', 'screen_name': 'MMratc', 'location': '', 'description': '', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 2, 'friends_count': 44, 'listed_count': 0, 'created_at': 'Tue Sep 24 17:18:37 +0000 2013', 'favourites_count': 0, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 1, 'lang': None, 'status': {'created_at': 'Sun Feb 10 00:17:03 +0000 2019', 'id': 1094389750679683078, 'id_str': '1094389750679683078', 'text': '@eugenegu @realDonaldTrump Get a life', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'eugenegu', 'name': 'Eugene Gu, MD', 'id': 65497475, 'id_str': '65497475', 'indices': [0, 9]}, {'screen_name': 'realDonaldTrump', 'name': 'Donald J. Trump', 'id': 25073877, 'id_str': '25073877', 'indices': [10, 26]}], 'urls': []}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': 1094371909926440961, 'in_reply_to_status_id_str': '1094371909926440961', 'in_reply_to_user_id': 65497475, 'in_reply_to_user_id_str': '65497475', 'in_reply_to_screen_name': 'eugenegu', 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'en'}, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', 'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': True, 'can_media_tag': True, 'followed_by': False, 'following': False, 'live_following': False, 'follow_request_sent': False, 'notifications': False, 'm ...
# dict_keys(['users', 'next_cursor', 'next_cursor_str', 'previous_cursor', 'previous_cursor_str', 'total_count'])
# Cursor now ==> 1657355963026040763
# {'users': [{'id': 3053243793, 'id_str': '3053243793', 'name': 'Lauren Hedberg', 'screen_name': 'SweeCutie1', 'location': '', 'description': 'Full time working mom of 2. Navy Sailor.', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 16, 'friends_count': 158, 'listed_count': 0, 'created_at': 'Sun Feb 22 17:35:18 +0000 2015', 'favourites_count': 419, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 363, 'lang': None, 'status': {'created_at': 'Sun Feb 02 14:27:50 +0000 2020', 'id': 1223976324693397505, 'id_str': '1223976324693397505', 'text': 'I’m bursting with avocado parent pride. If I win the Avo Carrier, I’ll be toting my avo baby around 24/7. RT to win… https://t.co/986klGe7ox', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/986klGe7ox', 'expanded_url': 'https://twitter.com/i/web/status/1223976324693397505', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'lang': 'en'}, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': True, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1175848768626970624/6JdrjRRu_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1175848768626970624/6JdrjRRu_normal.jpg', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': False, 'can_media_tag': False, 'followed_by': False, 'following': False, 'live_following': False, 'follow_request_sent': False, 'notifications': False, 'muting': False, 'blocking': False, 'blocked_by': False, 'translator_type': 'none'}, {'id': 227633906, 'id_str': '227633906', 'name': 'Brandi Summers', 'screen_name': 'Iamahoosiertoo', 'location': '', 'description': '', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 149, 'friends_count': 2891, 'listed_count': 0, 'created_at': 'Fri Dec 17 11:00:33 +0000 2010', 'favourites_count': 82, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 12677, 'lang': None, 'status': {'created_at': 'Sun Feb 02 08:20:36 +0000 2020', 'id': 1223883905595584512, 'id_str': '1223883905595584512', 'text': 'RT @AbsoluteDice: Sharing the love for a Valentine’s Giveaway 👇👇👇\nFollow &amp; RT to win one of THREE Absolute Dice Love Games 💖 Winners chosen…', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'AbsoluteDice', 'name': 'Absolute Dice', 'id': 768380722293960704, 'id_str': '768380722293960704', 'indices': [3, 16]}], 'urls': []}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Sun Feb 02 07:13:16 +0000 2020', 'id': 1223866959734943744, 'id_str': '1223866959 ...
# dict_keys(['users', 'next_cursor', 'next_cursor_str', 'previous_cursor', 'previous_cursor_str', 'total_count'])
# Cursor now ==> 1657341801880988530
# {'users': [{'id': 890653225430528005, 'id_str': '890653225430528005', 'name': '#FliptheSenate #HoldtheHouse #VoteBlue', 'screen_name': 'jo_jlsr3353', 'location': 'Florida, USA', 'description': 'Not a fan of this treasonous admin., GOP, or "Christian" conservatives. I\'m a fan of truth, justice & the progressive way, of rights for all. #resist #FBR NoDMs', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 1659, 'friends_count': 2431, 'listed_count': 2, 'created_at': 'Thu Jul 27 19:20:51 +0000 2017', 'favourites_count': 6651, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 15295, 'lang': None, 'status': {'created_at': 'Sun Feb 02 15:19:04 +0000 2020', 'id': 1223989216180342784, 'id_str': '1223989216180342784', 'text': "I'VE BEEN SAYING THIS FROM DAY ONE! #NoDemBashing https://t.co/KyD4oTHqJD", 'truncated': False, 'entities': {'hashtags': [{'text': 'NoDemBashing', 'indices': [36, 49]}], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/KyD4oTHqJD', 'expanded_url': 'https://twitter.com/r8dr4lfe75/status/1223988828836265984', 'display_url': 'twitter.com/r8dr4lfe75/sta…', 'indices': [50, 73]}]}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': True, 'quoted_status_id': 1223988828836265984, 'quoted_status_id_str': '1223988828836265984', 'retweet_count': 0, 'favorite_count': 1, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'lang': 'en'}, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1141415088173326336/fhy1b536_normal.png', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1141415088173326336/fhy1b536_normal.png', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/890653225430528005/1564153912', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': False, 'can_media_tag': True, 'followed_by': False, 'following': False, 'live_following': False, 'follow_request_sent': False, 'notifications': False, 'muting': False, 'blocking': False, 'blocked_by': False, 'translator_type': 'none'}, {'id': 1168493854196207617, 'id_str': '1168493854196207617', 'name': 'derek lewis', 'screen_name': 'derekle66535856', 'location': '', 'description': '', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 0, 'friends_count': 159, 'listed_count': 0, 'created_at': 'Mon Sep 02 12:00:36 +0000 2019', 'favourites_count': 0, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 85, 'lang': None, 'status': {'created_at': 'Sun Feb 02 13:05:46 +0000 2020', 'id': 1223955669138792448, 'id_str': '1223955669138792448', 'text': 'RT @nectarsleep: We’re kicking off the Big Game celebration early this year, so here’s our game plan:\nEnter for a chance to win a Nectar ma…', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'nectarsleep', 'name': 'Nectar Sleep', 'id': 868221035149119488, 'id_str': '868221035149119488', 'indices': [3, 15]}], 'urls': []}, 'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': No ...
# dict_keys(['users', 'next_cursor', 'next_cursor_str', 'previous_cursor', 'previous_cursor_str', 'total_count'])
# Cursor now ==> 1657313758334652987
# {'users': [{'id': 123553053, 'id_str': '123553053', 'name': 'Ishantha(Ish)  Samarasinghe', 'screen_name': 'ishanthasam', 'location': '', 'description': '', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 33, 'friends_count': 140, 'listed_count': 0, 'created_at': 'Tue Mar 16 12:59:32 +0000 2010', 'favourites_count': 3, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 3, 'lang': None, 'status': {'created_at': 'Sun Dec 15 12:49:41 +0000 2019', 'id': 1206194619509166080, 'id_str': '1206194619509166080', 'text': 'RT @SagaMilena: Learning how to learn is the only super power you need: https://t.co/2FtmOLNWWX https://t.co/foGUGy3dfn', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'SagaMilena', 'name': 'Saga Briggs', 'id': 569430602, 'id_str': '569430602', 'indices': [3, 14]}], 'urls': [{'url': 'https://t.co/2FtmOLNWWX', 'expanded_url': 'https://academyxi.com/blog/learning-how-to-learn-is-the-only-superpower-youll-need/', 'display_url': 'academyxi.com/blog/learning-…', 'indices': [72, 95]}], 'media': [{'id': 1204026078152593410, 'id_str': '1204026078152593410', 'indices': [96, 119], 'media_url': 'http://pbs.twimg.com/media/ELWPVsCXkAIRt5Y.png', 'media_url_https': 'https://pbs.twimg.com/media/ELWPVsCXkAIRt5Y.png', 'url': 'https://t.co/foGUGy3dfn', 'display_url': 'pic.twitter.com/foGUGy3dfn', 'expanded_url': 'https://twitter.com/SagaMilena/status/1204026086532812802/photo/1', 'type': 'photo', 'sizes': {'medium': {'w': 640, 'h': 480, 'resize': 'fit'}, 'small': {'w': 640, 'h': 480, 'resize': 'fit'}, 'large': {'w': 640, 'h': 480, 'resize': 'fit'}, 'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}}, 'source_status_id': 1204026086532812802, 'source_status_id_str': '1204026086532812802', 'source_user_id': 569430602, 'source_user_id_str': '569430602', 'features': {'medium': {'faces': []}, 'small': {'faces': []}, 'orig': {'faces': []}, 'large': {'faces': []}}}]}, 'extended_entities': {'media': [{'id': 1204026078152593410, 'id_str': '1204026078152593410', 'indices': [96, 119], 'media_url': 'http://pbs.twimg.com/media/ELWPVsCXkAIRt5Y.png', 'media_url_https': 'https://pbs.twimg.com/media/ELWPVsCXkAIRt5Y.png', 'url': 'https://t.co/foGUGy3dfn', 'display_url': 'pic.twitter.com/foGUGy3dfn', 'expanded_url': 'https://twitter.com/SagaMilena/status/1204026086532812802/photo/1', 'type': 'photo', 'sizes': {'medium': {'w': 640, 'h': 480, 'resize': 'fit'}, 'small': {'w': 640, 'h': 480, 'resize': 'fit'}, 'large': {'w': 640, 'h': 480, 'resize': 'fit'}, 'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}}, 'source_status_id': 1204026086532812802, 'source_status_id_str': '1204026086532812802', 'source_user_id': 569430602, 'source_user_id_str': '569430602', 'features': {'medium': {'faces': []}, 'small': {'faces': []}, 'orig': {'faces': []}, 'large': {'faces': []}}}]}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Mon Dec 09 13:12:43 +0000 2019', 'id': 1204026086532812802, 'id_str': '1204026086532812802', 'text': 'Learning how to learn is the only super power you need: https://t.co/2FtmOLNWWX https://t.co/foGUGy3dfn', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/2FtmOLNWWX', 'expanded_url': 'https://academyxi.com/blog/learning-how-to-learn-is-the-only-superpower-youll-need/', 'display_url': 'academyxi.com/blog/learning-…', 'indices': [56, 79]}], 'media': [{'id': 1204026078152593410, 'id_str': '1204026078152593410', 'indices': [80, 103], 'media_url': 'http://pbs.twimg.com/media/ELWPVsCXkAIRt5Y.png', 'media_url_https': 'https://pbs.twimg.com/medi ...
# dict_keys(['users', 'next_cursor', 'next_cursor_str', 'previous_cursor', 'previous_cursor_str', 'total_count'])
# Cursor now ==> 1657295002337098364
# {'users': [{'id': 1220765634922868736, 'id_str': '1220765634922868736', 'name': 'bryanfbsb@yahoo.com', 'screen_name': 'bryanfbsb', 'location': '', 'description': '', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 1, 'friends_count': 29, 'listed_count': 0, 'created_at': 'Fri Jan 24 17:49:53 +0000 2020', 'favourites_count': 0, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 12, 'lang': None, 'status': {'created_at': 'Sat Feb 01 20:13:25 +0000 2020', 'id': 1223700902550241280, 'id_str': '1223700902550241280', 'text': 'RT @iDropNews: Our iPhone 11 #giveaway ends February 19, 2020! Follow the link to earn your chances to win! (ARV: $699.99) https://t.co/vgd…', 'truncated': False, 'entities': {'hashtags': [{'text': 'giveaway', 'indices': [29, 38]}], 'symbols': [], 'user_mentions': [{'screen_name': 'iDropNews', 'name': 'iDrop News', 'id': 2513549293, 'id_str': '2513549293', 'indices': [3, 13]}], 'urls': []}, 'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Mon Jan 06 17:15:21 +0000 2020', 'id': 1214234006478180359, 'id_str': '1214234006478180359', 'text': 'Our iPhone 11 #giveaway ends February 19, 2020! Follow the link to earn your chances to win! (ARV: $699.99) https://t.co/vgd4epkU4K', 'truncated': False, 'entities': {'hashtags': [{'text': 'giveaway', 'indices': [14, 23]}], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/vgd4epkU4K', 'expanded_url': 'https://www.idropnews.com/giveaways/apple-iphone-11-giveaway/117141/', 'display_url': 'idropnews.com/giveaways/appl…', 'indices': [108, 131]}]}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 1050, 'favorite_count': 147, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'lang': 'en'}, 'is_quote_status': False, 'retweet_count': 1050, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'en'}, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1220766411561160705/sXUgWaOV_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1220766411561160705/sXUgWaOV_normal.jpg', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': False, 'can_media_tag': True, 'followed_by': False, 'following': False, 'live_following': False, 'follow_request_sent': False, 'notifications': False, 'muting': False, 'blocking': False, 'blocked_by': False, 'translator_type': 'none'}, {'id': 1218678540503322625, 'id_str': '1218678540503322625', 'name': 'Brenda Bartels', 'screen_name': 'BrendaBartels9', 'location': '', 'description': '', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 1, 'friends_count': 44, 'listed_count': 0, 'created_at': 'Sat Jan 18 23:36:44 +0000 2020', 'favourites_count': 0, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 42, 'lang': None, 'status': {'created_at': 'Sat Feb 01 03:41:5 ...
# dict_keys(['users', 'next_cursor', 'next_cursor_str', 'previous_cursor', 'previous_cursor_str', 'total_count'])
# Cursor now ==> 1657283846218049568
# {'users': [{'id': 1121368496082911232, 'id_str': '1121368496082911232', 'name': 'Skylar Walker', 'screen_name': 'SkylarW90174488', 'location': '', 'description': '', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 2, 'friends_count': 188, 'listed_count': 0, 'created_at': 'Thu Apr 25 11:00:58 +0000 2019', 'favourites_count': 84, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 177, 'lang': None, 'status': {'created_at': 'Sat Feb 01 12:30:19 +0000 2020', 'id': 1223584359845892096, 'id_str': '1223584359845892096', 'text': 'Check out the Deluxe Party Pack Sweepstakes that Birthday Supply Depot is having! https://t.co/ouSGp9DPS6 via @BirthdaySupplyD', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'BirthdaySupplyD', 'name': 'Crystal McLain', 'id': 20169225, 'id_str': '20169225', 'indices': [110, 126]}], 'urls': [{'url': 'https://t.co/ouSGp9DPS6', 'expanded_url': 'https://www.birthdaysupplydepot.com/sweepstakes/', 'display_url': 'birthdaysupplydepot.com/sweepstakes/', 'indices': [82, 105]}]}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'lang': 'en'}, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1128247890500050945/oBY7t6Bv_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1128247890500050945/oBY7t6Bv_normal.jpg', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': False, 'can_media_tag': True, 'followed_by': False, 'following': False, 'live_following': False, 'follow_request_sent': False, 'notifications': False, 'muting': False, 'blocking': False, 'blocked_by': False, 'translator_type': 'none'}, {'id': 3236680903, 'id_str': '3236680903', 'name': 'Brenda kough', 'screen_name': 'KoughBrenda', 'location': '', 'description': '', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 0, 'friends_count': 34, 'listed_count': 0, 'created_at': 'Fri Jun 05 04:49:05 +0000 2015', 'favourites_count': 6, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 52, 'lang': None, 'status': {'created_at': 'Fri Jan 31 02:14:47 +0000 2020', 'id': 1223067067957628932, 'id_str': '1223067067957628932', 'text': 'Hey Check it out! https://t.co/8Vn5agSI4W', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/8Vn5agSI4W', 'expanded_url': 'https://upvir.al/ref/nO32775256?track=twitter', 'display_url': 'upvir.al/ref/nO32775256…', 'indices': [18, 41]}]}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'lang': 'en'}, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabl ...
# dict_keys(['users', 'next_cursor', 'next_cursor_str', 'previous_cursor', 'previous_cursor_str', 'total_count'])
# Cursor now ==> 1657279485945478616
# {'users': [{'id': 2971935723, 'id_str': '2971935723', 'name': 'mother of many', 'screen_name': '10babiesmama', 'location': 'U.S. ', 'description': '', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 39, 'friends_count': 663, 'listed_count': 0, 'created_at': 'Sat Jan 10 20:18:32 +0000 2015', 'favourites_count': 105, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 1673, 'lang': None, 'status': {'created_at': 'Sun Feb 02 09:07:30 +0000 2020', 'id': 1223895708488687616, 'id_str': '1223895708488687616', 'text': "I'm so excited about this hand &amp; foot salve from @glowandgather! Help bring them to a store near you with… https://t.co/h2arZzKqpc", 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'glowandgather', 'name': 'glow + gather', 'id': 1084542647098732544, 'id_str': '1084542647098732544', 'indices': [53, 67]}], 'urls': [{'url': 'https://t.co/h2arZzKqpc', 'expanded_url': 'https://twitter.com/i/web/status/1223895708488687616', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [111, 134]}]}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'lang': 'en'}, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1055171213360807936/9ryM6Nxr_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1055171213360807936/9ryM6Nxr_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2971935723/1540407312', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'can_media_tag': True, 'followed_by': False, 'following': False, 'live_following': False, 'follow_request_sent': False, 'notifications': False, 'muting': False, 'blocking': False, 'blocked_by': False, 'translator_type': 'none'}, {'id': 4789119012, 'id_str': '4789119012', 'name': 'Laura Seigle', 'screen_name': 'LauraSeigle212', 'location': 'New York, NY', 'description': '', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 13, 'friends_count': 57, 'listed_count': 0, 'created_at': 'Wed Jan 20 15:08:55 +0000 2016', 'favourites_count': 285, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 20, 'lang': None, 'status': {'created_at': 'Wed Aug 21 19:24:53 +0000 2019', 'id': 1164257081798615042, 'id_str': '1164257081798615042', 'text': 'RT @kurteichenwald: I eagerly await the debates on @CNN and @MSNBC with one side screaming Trump is NOT the Second Coming of God, and the o…', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'kurteichenwald', 'name': 'Kurt Eichenwald', 'id': 215207998, 'id_str': '215207998', 'indices': [3, 18]}, {'screen_name': 'CNN', 'name': 'CNN', 'id': 759251, 'id_str': '759251', 'indices': [51, 55]}, {'screen_name': 'MSNBC', 'name': 'MSNBC', 'id': 2836421, 'id_str': '2836421', 'indices': [60, 66]}], 'urls': []}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_ ...
# dict_keys(['users', 'next_cursor', 'next_cursor_str', 'previous_cursor', 'previous_cursor_str', 'total_count'])
# Cursor now ==> 1657277027126181230
# {'users': [{'id': 1330263230, 'id_str': '1330263230', 'name': 'WILLIAM PEARSON', 'screen_name': 'BILLY22863', 'location': 'VICTORVILLE CA,', 'description': 'JUST CHECKING THIS OUT  FROM SOUTHERN CAL', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 28, 'friends_count': 316, 'listed_count': 0, 'created_at': 'Fri Apr 05 23:19:05 +0000 2013', 'favourites_count': 30, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 2781, 'lang': None, 'status': {'created_at': 'Sat Feb 01 13:31:05 +0000 2020', 'id': 1223599654853472257, 'id_str': '1223599654853472257', 'text': 'Fear Is Not an Option | https://t.co/XimSm8Jw3p https://t.co/qE4SAfEr6w', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/XimSm8Jw3p', 'expanded_url': 'http://CBN.com', 'display_url': 'CBN.com', 'indices': [24, 47]}, {'url': 'https://t.co/qE4SAfEr6w', 'expanded_url': 'http://fw.to/KpslqyD', 'display_url': 'fw.to/KpslqyD', 'indices': [48, 71]}]}, 'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'lang': 'en'}, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '0099B9', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme4/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme4/bg.gif', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/3496490424/39a1fb8c552a7bd428ca45e412e0d646_normal.jpeg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/3496490424/39a1fb8c552a7bd428ca45e412e0d646_normal.jpeg', 'profile_link_color': '0099B9', 'profile_sidebar_border_color': '5ED4DC', 'profile_sidebar_fill_color': '95E8EC', 'profile_text_color': '3C3940', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'can_media_tag': True, 'followed_by': False, 'following': False, 'live_following': False, 'follow_request_sent': False, 'notifications': False, 'muting': False, 'blocking': False, 'blocked_by': False, 'translator_type': 'none'}, {'id': 509022811, 'id_str': '509022811', 'name': 'Jim Coston', 'screen_name': 'TrainCoston', 'location': 'Chicago, IL', 'description': 'Dad, husband, son, brother, attorney, railroader, Wildcats, Sox, Hawks & Bulls fan.', 'url': 'https://t.co/8Tc6NLTXYX', 'entities': {'url': {'urls': [{'url': 'https://t.co/8Tc6NLTXYX', 'expanded_url': 'http://ccrail.com/', 'display_url': 'ccrail.com', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 344, 'friends_count': 1373, 'listed_count': 10, 'created_at': 'Wed Feb 29 16:52:52 +0000 2012', 'favourites_count': 16622, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 7490, 'lang': None, 'status': {'created_at': 'Sun Feb 02 01:04:36 +0000 2020', 'id': 1223774184817545222, 'id_str': '1223774184817545222', 'text': 'RT @Lawrence: The 49 Senators who lost the vote on witnesses represent 19 million MORE people than the 51 Senators who won.', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'Lawrence', 'name': "Lawrence O'Donnell", 'id': 158426909, 'id_str': '158426909', 'indices': [3, 12]}], 'urls': []}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_rep ...
# dict_keys(['users', 'next_cursor', 'next_cursor_str', 'previous_cursor', 'previous_cursor_str', 'total_count'])
# Cursor now ==> 1657276063267295790
# {'users': [{'id': 28593425, 'id_str': '28593425', 'name': 'Michael K Dean', 'screen_name': 'moreblues', 'location': 'State of Maine in USA', 'description': 'Educator, student, and semi-pro musician.I love God, my family, and music.', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 126, 'friends_count': 461, 'listed_count': 2, 'created_at': 'Fri Apr 03 16:09:32 +0000 2009', 'favourites_count': 94, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 976, 'lang': None, 'status': {'created_at': 'Thu Jan 30 23:11:19 +0000 2020', 'id': 1223020900062318593, 'id_str': '1223020900062318593', 'text': 'RT @hibbing_mark: @DudeShopping Nice prize', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'hibbing_mark', 'name': 'mark hibbing', 'id': 947685836585426945, 'id_str': '947685836585426945', 'indices': [3, 16]}, {'screen_name': 'DudeShopping', 'name': 'Dude Shopping', 'id': 2379593869, 'id_str': '2379593869', 'indices': [18, 31]}], 'urls': []}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Thu Jan 30 18:39:38 +0000 2020', 'id': 1222952528716808192, 'id_str': '1222952528716808192', 'text': '@DudeShopping Nice prize', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'DudeShopping', 'name': 'Dude Shopping', 'id': 2379593869, 'id_str': '2379593869', 'indices': [0, 13]}], 'urls': []}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': 1222922650688925696, 'in_reply_to_status_id_str': '1222922650688925696', 'in_reply_to_user_id': 2379593869, 'in_reply_to_user_id_str': '2379593869', 'in_reply_to_screen_name': 'DudeShopping', 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 1, 'favorite_count': 1, 'favorited': False, 'retweeted': False, 'lang': 'en'}, 'is_quote_status': False, 'retweet_count': 1, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'en'}, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/584448479914754048/dkvzC-KK_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/584448479914754048/dkvzC-KK_normal.jpg', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'can_media_tag': True, 'followed_by': False, 'following': False, 'live_following': False, 'follow_request_sent': False, 'notifications': False, 'muting': False, 'blocking': False, 'blocked_by': False, 'translator_type': 'none'}, {'id': 1657659792, 'id_str': '1657659792', 'name': 'Quinn Whimley', 'screen_name': 'MissQuinnnn', 'location': 'Kansas City, KS', 'description': '', 'url': 'https://t.co/UOLgLgP0B2', 'entities': {'url': {'urls': [{'url': 'https://t.co/UOLgLgP0B2', 'expanded_url': 'https://www.facebook.com/quinn.a.cooper.1', 'display_url': 'facebook.com/quinn.a.cooper…', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 56, 'friends_count': 689, 'listed_count': 2, 'created_at': 'Fri Aug 09 12:50:11 +0000 2013', 'favourites_coun ...
# dict_keys(['users', 'next_cursor', 'next_cursor_str', 'previous_cursor', 'previous_cursor_str', 'total_count'])
# Cursor now ==> 1657268336946138493
# {'users': [{'id': 325678621, 'id_str': '325678621', 'name': 'Jazz Patterson', 'screen_name': 'Sirensmoking', 'location': 'Nashville, TN', 'description': 'Just a Metal singer. New EP Knife Out Now!!', 'url': 'https://t.co/PjgKdXh7fM', 'entities': {'url': {'urls': [{'url': 'https://t.co/PjgKdXh7fM', 'expanded_url': 'https://open.spotify.com/artist/7GdvBRUW6z8vBCDvkfDHX9?si=K29NeUa3Qb-K5NL0uLVcjg', 'display_url': 'open.spotify.com/artist/7GdvBRU…', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 3901, 'friends_count': 4975, 'listed_count': 8, 'created_at': 'Tue Jun 28 17:55:52 +0000 2011', 'favourites_count': 6279, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 3495, 'lang': None, 'status': {'created_at': 'Sat Feb 01 21:44:56 +0000 2020', 'id': 1223723933209366529, 'id_str': '1223723933209366529', 'text': '@NationOfCowboys Fair', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'NationOfCowboys', 'name': 'Montana ✭™', 'id': 1175575841377521664, 'id_str': '1175575841377521664', 'indices': [0, 16]}], 'urls': []}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': 1223722659625807872, 'in_reply_to_status_id_str': '1223722659625807872', 'in_reply_to_user_id': 1175575841377521664, 'in_reply_to_user_id_str': '1175575841377521664', 'in_reply_to_screen_name': 'NationOfCowboys', 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 1, 'favorited': False, 'retweeted': False, 'lang': 'fr'}, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1084978193390624769/BnU-afZR_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1084978193390624769/BnU-afZR_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/325678621/1551134864', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'can_media_tag': True, 'followed_by': False, 'following': False, 'live_following': False, 'follow_request_sent': False, 'notifications': False, 'muting': False, 'blocking': False, 'blocked_by': False, 'translator_type': 'none'}, {'id': 776103962286039040, 'id_str': '776103962286039040', 'name': 'Pet Thedford', 'screen_name': 'petthedf0rd', 'location': '', 'description': '', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 0, 'friends_count': 39, 'listed_count': 0, 'created_at': 'Wed Sep 14 17:02:58 +0000 2016', 'favourites_count': 0, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 0, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', 'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_prof ...
# dict_keys(['users', 'next_cursor', 'next_cursor_str', 'previous_cursor', 'previous_cursor_str', 'total_count'])
# Cursor now ==> 1657259190422081729
# {'errors': [{'message': 'Rate limit exceeded', 'code': 88}]}
# dict_keys(['errors'])
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-74ce32a66b96> in <module>
#       7     print(js)
#       8     print(js.keys())
# ----> 9     cursor = js['next_cursor']
#      10     print('Cursor now ==>', cursor)
#      11     jsonlst.append(js)
#
# KeyError: 'next_cursor'

# %%
print(jsonlst[0]['users'][0]['id'])
print(jsonlst[0]['users'][0]['name'])
# Out:
# 16090812
# Heather Rosen

# %%
print(len(jsonlst))
for i in jsonlst:
    print(type(i))
    print(type(i['users']))
    print(type(i['users'][0]))
    print(len(i['users']))
    print(i['users'][0]['name'])
# Out:
# 15
# <class 'dict'>
# <class 'list'>
# <class 'dict'>
# 20
# Heather Rosen
# <class 'dict'>
# <class 'list'>
# <class 'dict'>
# 20
# Mooninspired
# <class 'dict'>
# <class 'list'>
# <class 'dict'>
# 20
# zencodecat
# <class 'dict'>
# <class 'list'>
# <class 'dict'>
# 20
# Melissa Medina
# <class 'dict'>
# <class 'list'>
# <class 'dict'>
# 20
# Bryan Chiapparelli
# <class 'dict'>
# <class 'list'>
# <class 'dict'>
# 20
# Jenna Debbs
# <class 'dict'>
# <class 'list'>
# <class 'dict'>
# 20
# Lauren Hedberg
# <class 'dict'>
# <class 'list'>
# <class 'dict'>
# 20
# #FliptheSenate #HoldtheHouse #VoteBlue
# <class 'dict'>
# <class 'list'>
# <class 'dict'>
# 20
# Ishantha(Ish)  Samarasinghe
# <class 'dict'>
# <class 'list'>
# <class 'dict'>
# 20
# bryanfbsb@yahoo.com
# <class 'dict'>
# <class 'list'>
# <class 'dict'>
# 20
# Skylar Walker
# <class 'dict'>
# <class 'list'>
# <class 'dict'>
# 20
# mother of many
# <class 'dict'>
# <class 'list'>
# <class 'dict'>
# 20
# WILLIAM PEARSON
# <class 'dict'>
# <class 'list'>
# <class 'dict'>
# 20
# Michael K Dean
# <class 'dict'>
# <class 'list'>
# <class 'dict'>
# 20
# Jazz Patterson

# %%
import twitterfuncs2 as twt2
from importlib import reload
reload(twt2)
# Out:
# <module 'twitterfuncs2' from 'C:\\Users\\afs95\\MyPython\\DataScienceGA\\DS_work\\DS_repo\\Homework\\Unit1\\twitterfuncs2.py'>

# %%
print(twt2.friends_of_friends.__doc__)
# Out:
#     parameters
#     ------------
#     names: list of length two
#         list of two Twitter users to compare friends list with
#     keys: list; default set to None
#         list of keys to return for information about each user
#     to_df: bool; default set to False
#         returns a DataFrame object if set to True
#     full_search: bool; default set to False
#         if set to true, will cursor through all followers of the
#         users until there are no more, or api limit has been
#         exceeded
#
#     return
#     ------------
#     list or DataFrame of data objects for each user that two Twitter
#     users have in common

# %%
fof2 = twt2.friends_of_friends(['ezraklein', 'tylercowen'], full_search=True, to_df=True)
# Out:
# Key Error 'next_cursor'
# [{'message': 'Rate limit exceeded', 'code': 88}]
# Key Error 'next_cursor'
# [{'message': 'Rate limit exceeded', 'code': 88}]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-70-4a826322f391> in <module>
# ----> 1 fof2 = twt2.friends_of_friends(['ezraklein', 'tylercowen'], full_search=True, to_df=True)
#
# ~\MyPython\DataScienceGA\DS_work\DS_repo\Homework\Unit1\twitterfuncs2.py in friends_of_friends(names, keys, to_df, full_search)
#      94     # makes one whole flat list of user dicts from each name
#      95     name1users = [user_dict for lod in users_dict[names[0]] for users in lod for user in users]
# ---> 96     name2users = [user_dict for lod in users_dict[names[1]] for users in lod for user in users]
#      97
#      98     # loop through each item in each list to see if users exist in both lists
#
# KeyError: 'tylercowen'

# %%
dict_of_user_lod = {}
for user in ['sdlkfjsfewjclmfocmeijc', 'tylercowen']:
    jsonlst = []
    cursor = -1
    try:
        while cursor:
            query5 = requests.get(flwerlist + '?' + 'screen_name=%s' % user + '&cursor=%s' % cursor, auth=auth)
            js = query5.json()
            cursor = js['next_cursor']
            print('Cursor now ==>', cursor)
            if not user in dict_of_user_lod.keys():
                dict_of_user_lod[user] = [js]
            else:
                dict_of_user.append(js)
            
    except KeyError as e:
        print('KeyError:', e)
        print(js)
# Out:
# KeyError: 'next_cursor'
# {'errors': [{'message': 'Rate limit exceeded', 'code': 88}]}
# KeyError: 'next_cursor'
# {'errors': [{'message': 'Rate limit exceeded', 'code': 88}]}

# %%
dict_of_user_lod.keys()
# Out:
# dict_keys([])

# %%
dict_of_user_lod['ezraklein']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-59-44c21ed286a8> in <module>
# ----> 1 dict_of_user_lod['ezraklein']
#
# KeyError: 'ezraklein'

# %%
reload(twt)
# Out:
# <module 'twitterfuncs' from 'C:\\Users\\afs95\\MyPython\\DataScienceGA\\DS_work\\DS_repo\\Homework\\Unit1\\twitterfuncs.py'>

# %%
twt.friends_of_friends(['Beyonce', 'MariahCarey'], to_df=True)
# Out:
# dict_keys(['Beyonce', 'MariahCarey'])
# <class 'list'>
# <class 'dict'>
#            id      id_str      name screen_name      location  \
# 0  2741467349  2741467349  chyydoll  slimedolll  New York, NY
#
#                                  description   url  \
# 0  22. 🦋NYC/MIAMI/ATL✈️ Future in Fashion 🐍🦄  None
#
#                         entities  protected  followers_count  ...  \
# 0  {'description': {'urls': []}}      False                5  ...
#
#    can_media_tag  followed_by following  live_following follow_request_sent  \
# 0           True        False     False           False               False
#
#   notifications  muting  blocking  blocked_by translator_type
# 0         False   False     False       False            none
#
# [1 rows x 49 columns]

# %%
twt.friends_of_friends(['Beyonce', 'MariahCarey'], keys=['id', 'name'], to_df=True)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
reload(twt2)
twt2.friends_of_friends(['Beyonce', 'MariahCarey'], to_df=True)
# Out:
#                     id               id_str      name screen_name location  \
# 0  1202731258725519368  1202731258725519368  Tramesia    Trvmesia
#
#               description   url                       entities  protected  \
# 0  𝙟𝙪𝙨𝙩 𝙗𝙚𝙞𝙣𝙜 𝙣𝙤𝙨𝙚𝙮 𝙡𝙪𝙫😆💗  None  {'description': {'urls': []}}       True
#
#    followers_count  ...  can_media_tag  followed_by following  live_following  \
# 0                0  ...          False        False     False           False
#
#   follow_request_sent notifications  muting  blocking  blocked_by  \
# 0               False         False   False     False       False
#
#   translator_type
# 0            none
#
# [1 rows x 48 columns]

# %%
reload(twt)
twt.friends_of_friends(['Beyonce', 'MariahCarey'], to_df=True)
# Out:
#                     id               id_str      name screen_name location  \
# 0  1202731258725519368  1202731258725519368  Tramesia    Trvmesia
#
#               description   url                       entities  protected  \
# 0  𝙟𝙪𝙨𝙩 𝙗𝙚𝙞𝙣𝙜 𝙣𝙤𝙨𝙚𝙮 𝙡𝙪𝙫😆💗  None  {'description': {'urls': []}}       True
#
#    followers_count  ...  can_media_tag  followed_by following  live_following  \
# 0                0  ...          False        False     False           False
#
#   follow_request_sent notifications  muting  blocking  blocked_by  \
# 0               False         False   False     False       False
#
#   translator_type
# 0            none
#
# [1 rows x 48 columns]

# %%
reload(twt2)
#twt2.friends_of_friends_search(['Beyonce', 'MariahCarey'], to_df=True, full_search=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-7e8e1d60fc50> in <module>
# ----> 1 reload(twt2)
#       2 #twt2.friends_of_friends_search(['Beyonce', 'MariahCarey'], to_df=True, full_search=False)
#
# NameError: name 'reload' is not defined

# %%
import twitterfuncs as twt
# list_dicts = twt.friends_of_friends(['Beyonce', 'MariahCarey'], to_df=False)

# %%
twt.friends_of_friends(['Beyonce', 'MariahCarey'], to_df=True, full_search=False)
# Out:
# No users in common
# []

# %%
list_dicts
# Out:
# []

# %%
twt.friends_of_friends(['Beyonce', 'MariahCarey'], to_df=True, full_search=True)
# Out:
# Key Error 'next_cursor'
# [{'message': 'Rate limit exceeded', 'code': 88}]
# Key Error 'next_cursor'
# [{'message': 'Rate limit exceeded', 'code': 88}]
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-3-c9b95e2adb5e> in <module>
# ----> 1 twt.friends_of_friends(['Beyonce', 'MariahCarey'], to_df=True, full_search=True)
#
# ~\MyPython\DataScienceGA\DS_work\DS_repo\Homework\Unit1\twitterfuncs.py in friends_of_friends(names, keys, to_df, full_search)
#     212     # Due to a issues with the api rate limit, the function will end here
#     213     # if follower information wasn't returned for each name requested
# --> 214     assert (len(name_flws.keys()) == 2), 'Both names were not returned'
#     215
#     216     # check to see if screen names exist
#
# AssertionError: Both names were not returned

# %%
print(twt.friends_of_friends.__doc__)
# Out:
#     parameters
#     ------------
#     names: list of length two
#         list of two Twitter users to compare friends list with
#     keys: list; default set to None
#         list of keys to return for information about each user
#     to_df: bool; default set to False
#         returns a DataFrame object if set to True
#     full_search: bool; default set to False
#         if set to True, will cursor through all followers of the
#         users until there are no more, or api limit has been
#         exceeded
#
#     return
#     ------------
#     list or DataFrame of data objects for each user that two Twitter
#     users have in common
