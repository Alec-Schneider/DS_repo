# %%
import pandas as pd

# %%
train = pd.read_csv('data/train.csv')
test = pd.read_csv('data/test.csv')

# %%
import numpy as np
num_cols = train.select_dtypes(include=np.number).columns.tolist()
train_means = train[num_cols].mean()
train_stds = train[num_cols].std()

# %%
train[num_cols] -= train[num_cols].mean()
train[num_cols] /= train[num_cols].std()

# %%
num_cols.remove('SalePrice')

# %%
test[num_cols] -= train_means
test[num_cols] /= train_stds

# %%
test.describe()
# Out:
#                 Id   MSSubClass      LotArea  OverallQual  OverallCond  \
# count  1459.000000  1459.000000  1459.000000  1459.000000  1459.000000
# mean      3.461730     0.011373    -0.069898    -0.014819    -0.019355
# std       0.999315     1.010551     0.496482     1.038912     1.000845
# min       1.732644    -0.872264    -0.906381    -3.687150    -4.111561
# 25%       2.597187    -0.872264    -0.313170    -0.794879    -0.517023
# 50%       3.461730    -0.163054    -0.111993    -0.071812    -0.517023
# 75%       4.326273     0.309753     0.100255     0.651256     0.381612
# max       5.190816     3.146594     4.616967     2.820459     3.077516
#
#          YearBuilt    GrLivArea     1stFlrSF     2ndFlrSF  GrLivArea.1  \
# count  1459.000000  1459.000000  1459.000000  1459.000000  1459.000000
# mean      0.002979    -0.055983    -0.015759    -0.048163    -0.055983
# std       1.006197     0.924042     1.029949     0.963535     0.924042
# min      -3.054932    -2.109429    -1.954606    -0.794891    -2.109429
# 25%      -0.604836    -0.757333    -0.747894    -0.794891    -0.757333
# 50%       0.057352    -0.158833    -0.216320    -0.794891    -0.158833
# 75%       0.984415     0.391140     0.568754     0.753691     0.391140
# max       1.282400     6.811931    10.172007     3.470582     6.811931
#
#           FullBath     HalfBath  GarageYrBlt   GarageCars
# count  1459.000000  1459.000000  1381.000000  1458.000000
# mean      0.010656    -0.010382    -0.031792    -0.001345
# std       1.007758     1.000261     1.070533     1.038311
# min      -2.840849    -0.761360    -3.382223    -2.364630
# 25%      -1.025689    -0.761360    -0.790052    -1.026506
# 50%       0.789470    -0.761360     0.020002     0.311618
# 75%       0.789470     1.227165     0.951563     0.311618
# max       4.419789     3.215690     9.254613     4.325989

# %%
pd.get_dummies(train)
# Out:
#             Id  MSSubClass   LotArea  OverallQual  OverallCond  YearBuilt  \
# 0    -1.730272    0.073350 -0.207071     0.651256    -0.517023   1.050634
# 1    -1.727900   -0.872264 -0.091855    -0.071812     2.178881   0.156680
# 2    -1.725528    0.073350  0.073455     0.651256    -0.517023   0.984415
# 3    -1.723156    0.309753 -0.096864     0.651256    -0.517023  -1.862993
# 4    -1.720785    0.073350  0.375020     1.374324    -0.517023   0.951306
# ...        ...         ...       ...          ...          ...        ...
# 1455  1.720785    0.073350 -0.260471    -0.071812    -0.517023   0.918196
# 1456  1.723156   -0.872264  0.266316    -0.071812     0.381612   0.222899
# 1457  1.725528    0.309753 -0.147760     0.651256     3.077516  -1.002149
# 1458  1.727900   -0.872264 -0.080133    -0.794879     0.381612  -0.704164
# 1459  1.730272   -0.872264 -0.058092    -0.794879     0.381612  -0.207523
#
#       GrLivArea  1stFlrSF  2ndFlrSF  GrLivArea.1  ...  Neighborhood_Veenker  \
# 0      0.370207 -0.793162  1.161454     0.370207  ...                     0
# 1     -0.482347  0.257052 -0.794891    -0.482347  ...                     1
# 2      0.514836 -0.627611  1.188943     0.514836  ...                     0
# 3      0.383528 -0.521555  0.936955     0.383528  ...                     0
# 4      1.298881 -0.045596  1.617323     1.298881  ...                     0
# ...         ...       ...       ...          ...  ...                   ...
# 1455   0.250316 -0.542249  0.794925     0.250316  ...                     0
# 1456   1.061003  2.354894 -0.794891     1.061003  ...                     0
# 1457   1.569110  0.065634  1.844112     1.569110  ...                     0
# 1458  -0.832502 -0.218907 -0.794891    -0.832502  ...                     0
# 1459  -0.493765  0.241532 -0.794891    -0.493765  ...                     0
#
#       GarageType_2Types  GarageType_Attchd  GarageType_Basment  \
# 0                     0                  1                   0
# 1                     0                  1                   0
# 2                     0                  1                   0
# 3                     0                  0                   0
# 4                     0                  1                   0
# ...                 ...                ...                 ...
# 1455                  0                  1                   0
# 1456                  0                  1                   0
# 1457                  0                  1                   0
# 1458                  0                  1                   0
# 1459                  0                  1                   0
#
#       GarageType_BuiltIn  GarageType_CarPort  GarageType_Detchd  \
# 0                      0                   0                  0
# 1                      0                   0                  0
# 2                      0                   0                  0
# 3                      0                   0                  1
# 4                      0                   0                  0
# ...                  ...                 ...                ...
# 1455                   0                   0                  0
# 1456                   0                   0                  0
# 1457                   0                   0                  0
# 1458                   0                   0                  0
# 1459                   0                   0                  0
#
#       GarageFinish_Fin  GarageFinish_RFn  GarageFinish_Unf
# 0                    0                 1                 0
# 1                    0                 1                 0
# 2                    0                 1                 0
# 3                    0                 0                 1
# 4                    0                 1                 0
# ...                ...               ...               ...
# 1455                 0                 1                 0
# 1456                 0                 0                 1
# 1457                 0                 1                 0
# 1458                 0                 0                 1
# 1459                 1                 0                 0
#
# [1460 rows x 54 columns]
