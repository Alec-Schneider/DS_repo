# %%
pwd
# Out:
# 'C:\\Users\\afs95\\MyPython\\DataScienceGA\\DS_work\\DS_repo\\Lectures\\Unit1\\Class3'

# %%
import os
path = '../../../../../../../Downloads'
os.listdir(path)[-5:]
# Out:
# ['vs_community__2067829441.1533606942.exe',
#  'WEFYRF83MTUuUmVtb3RlIFBDICRQMTA0NQ--.ica',
#  'Workbook.graphing-functions.pdf',
#  'World_Bank_CO2.xlsx',
#  'ZILLOW-C25709_ZRISFRR.csv']

# %%
myself = {
    'name': 'Jonathan',
    'age': 34,
    'interests': ['python', 'hiking', 'basketball']
}

# %%
for i, v in myself.items():
    print(i, '==>', v)
# Out:
# name ==> Jonathan
# age ==> 34
# interests ==> ['python', 'hiking', 'basketball']

# %%
[v for i, v in myself.items()]
# Out:
# ['Jonathan', 34, ['python', 'hiking', 'basketball']]

# %%
myself['name']
# Out:
# 'Jonathan'

# %%
import requests

# %%
url = 'https://api.census.gov/data.json'

# %%
req = requests.get(url)

# %%
#help(req)

# %%
data = req.json()

# %%
data['dataset'][3]['c_dataset'][0]
# Out:
# 'cbp'

# %%
c_dataset = [item['c_dataset'] for item in data['dataset']]
print(c_dataset[:5])
print(len(c_dataset))
# Out:
# [['cbp'], ['zbp'], ['cbp'], ['cbp'], ['cbp']]
# 405

# %%
data.keys()
# Out:
# dict_keys(['@context', '@id', '@type', 'conformsTo', 'describedBy', 'dataset'])

# %%
url = 'https://api.github.com'

# %%
path = '/users/Blitz33697/repos'

# %%
url+path
# Out:
# 'https://api.github.com/users/Blitz33697/repos'

# %%
my_repos = requests.get(url + path).json()

# %%
print(len(my_repos))
my_repos
# Out:
# 7
# [{'id': 229449589,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkyMjk0NDk1ODk=',
#   'name': 'atom',
#   'full_name': 'Blitz33697/atom',
#   'private': False,
#   'owner': {'login': 'Blitz33697',
#    'id': 36939584,
#    'node_id': 'MDQ6VXNlcjM2OTM5NTg0',
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/36939584?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Blitz33697',
#    'html_url': 'https://github.com/Blitz33697',
#    'followers_url': 'https://api.github.com/users/Blitz33697/followers',
#    'following_url': 'https://api.github.com/users/Blitz33697/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Blitz33697/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Blitz33697/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Blitz33697/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Blitz33697/orgs',
# ...

# %%
my_repos[0]['owner']
# Out:
# {'login': 'Blitz33697',
#  'id': 36939584,
#  'node_id': 'MDQ6VXNlcjM2OTM5NTg0',
#  'avatar_url': 'https://avatars1.githubusercontent.com/u/36939584?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/Blitz33697',
#  'html_url': 'https://github.com/Blitz33697',
#  'followers_url': 'https://api.github.com/users/Blitz33697/followers',
#  'following_url': 'https://api.github.com/users/Blitz33697/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/Blitz33697/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/Blitz33697/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/Blitz33697/subscriptions',
#  'organizations_url': 'https://api.github.com/users/Blitz33697/orgs',
#  'repos_url': 'https://api.github.com/users/Blitz33697/repos',
#  'events_url': 'https://api.github.com/users/Blitz33697/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/Blitz33697/received_events',
#  'type': 'User',
# ...

# %%
import pandas as pd

# %%
repos1 = pd.read_csv("GitHub Repos.csv")

# %%
repos1
# Out:
#                       Name                                      Repo
# 0         Jonathan Bechtel        https://github.com/JonathanBechtel
# 1               Aoife Duna              https://github.com/aoifeduna
# 2           Christos Simos               https://github.com/simoschr
# 3            Brittani Kauf           https://github.com/brittanikauf
# 4          Stanford Turner              https://github.com/sturner08
# 5          Shelly Seroussi              https://github.com/sturner08
# 6                 Shela Wu                 https://github.com/misowu
# 7          Rishabh Chandra       https://github.com/rishabhchandra35
# 8   Behrang "Brian" Bidadi              https://github.com/brianb888
# 9           Alec Schneider             https://github.com/Blitz33697
# 10          Taku Takamatsu         https://github.com/taku-takamatsu
# 11          Lindsey Gumann                https://github.com/lgumann
# 12            David Hurley               https://github.com/davehurl
# ...

# %%
with open('GitHub Repos.csv', 'r') as f:
    repos2 = f.readlines()

# %%
repos2
# Out:
# ['Name,Repo\n',
#  'Jonathan Bechtel,https://github.com/JonathanBechtel\n',
#  'Aoife Duna,https://github.com/aoifeduna\n',
#  'Christos Simos,https://github.com/simoschr\n',
#  'Brittani Kauf,https://github.com/brittanikauf\n',
#  'Stanford Turner,https://github.com/sturner08\n',
#  'Shelly Seroussi,https://github.com/sturner08\n',
#  'Shela Wu,https://github.com/misowu\n',
#  'Rishabh Chandra,https://github.com/rishabhchandra35\n',
#  '"Behrang ""Brian"" Bidadi",https://github.com/brianb888\n',
#  'Alec Schneider,https://github.com/Blitz33697\n',
#  'Taku Takamatsu,https://github.com/taku-takamatsu\n',
#  'Lindsey Gumann,https://github.com/lgumann\n',
#  'David Hurley,https://github.com/davehurl\n',
#  'Kina Abe,https://github.com/kinaabe57\n',
#  'Elyse Chu,https://github.com/elysechu\n',
#  'Michael Lawlor,https://github.com/lawlormj/sample_work\n',
#  'Emily Lam,https://github.com/emilylam98\n',
#  'Mike Golodner,https://github.com/mgolodner/ga_repo.git\n',
# ...
